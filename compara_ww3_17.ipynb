# %%
'''
Comparacao dos dados da BMOP05 e WW3
no dia 17 e 18 de Maio de 2016
* Onde ocorreu ondas de até 5 m
'''
# %matplotlib inline
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
'''
Carrega dados
'''

pathnamem = os.environ['HOME'] + '/Dropbox/projetos/BMOP/Sistemas-BMOP/Processamento/modelagem/'
pathnamed = os.environ['HOME'] + '/Dropbox/projetos/BMOP/Sistemas-BMOP/Processamento/dados/BMOBR05_CF1/op/'

dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H')

#carrega modelo ww3
dm = pd.read_table(pathnamem + 'PNBOIA_izabel_17_18.txt', sep='\s*', 
                   parse_dates=[['#ANO', 'M', 'S', 'H']], date_parser=dateparse, index_col='#ANO_M_S_H')

#carrega os dados da boia
db = pd.read_csv(pathnamed + 'Dados_BMOBR05.csv', index_col='date', parse_dates=True)
# Out:
# /usr/local/python/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:12: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
fig = plt.figure(figsize=(12,10))
ax1 = fig.add_subplot(311)
ax1.plot(dm.index, dm.Hs,'-o')
ax1.plot(db.index, dd.hs,'-o')
ax1.set_xlim(dm.index[0], dm.index[-1])
ax1.set_ylim(0,6)
ax1.grid()
ax1.set_ylabel('Hs (m)')
ax1.legend(['BMOP05','WW3'], loc=0)
ax2 = fig.add_subplot(312)
ax2.plot(dm.index, dm.Tp,'o')
ax2.plot(db.index, db.tp,'o')
ax2.set_xlim(dm.index[0], dm.index[-1])
ax2.grid()
ax2.set_ylabel('Tp (s)')
ax2.set_ylim(0,20)
ax3 = fig.add_subplot(313)
ax3.plot(dm.index, dm.Dp,'o')
ax3.plot(db.index, db.dp,'o')
ax3.set_xlim(dm.index[0], dm.index[-1])
ax3.grid()
ax3.set_ylabel('Dp (deg)')
ax3.set_ylim(0,360)

fig.savefig('Onda_20160517.png')

# %%
dd
# Out:
#                       ate   bat      bp  con      dir1      dir2      dir3  \
# date
# 2016-02-22 10:00:00  27.2  13.8  1015.3  326    -32431    -32431    -32431
# 2016-02-22 11:00:00  27.3  13.8  1014.9  307    -32431    -32431    -32431
# 2016-02-22 12:00:00  27.5  13.3  1014.6  303    -32431    -32431    -32431
# 2016-02-22 13:00:00  27.6  13.3  1014.2  314    -32431    -32431    -32431
# 2016-02-22 14:00:00  26.9  13.3  1014.0  305    -32431    -32431    -32431
# 2016-02-22 15:00:00  26.8  13.3  1013.7  314       237       194       222
# 2016-02-22 16:00:00  26.8  13.3  1013.5  307       282        96       344
# 2016-02-22 17:00:00  26.9  13.3  1013.7  311       264        83        77
# 2016-02-22 18:00:00  26.9  12.9  1014.2  313       278        73        16
# 2016-02-22 19:00:00  26.9  12.8  1014.6  318       271        83       299
# 2016-02-22 20:00:00  27.0  12.8  1015.3  317       255       274       281
# ...
